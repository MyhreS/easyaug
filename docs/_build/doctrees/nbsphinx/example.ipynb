# %% [markdown]
# # An example of viewing, preparing and augmenting

# %%
# Installed the framework
# !pip install easyaug
# Out:
# Requirement already satisfied: easyaug in c:\other\github\test_easyaug\venv\lib\site-packages (1.0)
# Requirement already satisfied: matplotlib in c:\other\github\test_easyaug\venv\lib\site-packages (from easyaug) (3.5.1)
# Requirement already satisfied: imgaug in c:\other\github\test_easyaug\venv\lib\site-packages (from easyaug) (0.4.0)
# Requirement already satisfied: numpy in c:\other\github\test_easyaug\venv\lib\site-packages (from easyaug) (1.22.3)
# Requirement already satisfied: imageio in c:\other\github\test_easyaug\venv\lib\site-packages (from easyaug) (2.16.1)
# Requirement already satisfied: pillow>=8.3.2 in c:\other\github\test_easyaug\venv\lib\site-packages (from imageio->easyaug) (9.1.0)
# Requirement already satisfied: scikit-image>=0.14.2 in c:\other\github\test_easyaug\venv\lib\site-packages (from imgaug->easyaug) (0.19.2)
# Requirement already satisfied: Shapely in c:\other\github\test_easyaug\venv\lib\site-packages (from imgaug->easyaug) (1.8.1.post1)
# Requirement already satisfied: opencv-python in c:\other\github\test_easyaug\venv\lib\site-packages (from imgaug->easyaug) (4.5.5.64)
# Requirement already satisfied: scipy in c:\other\github\test_easyaug\venv\lib\site-packages (from imgaug->easyaug) (1.8.0)
# Requirement already satisfied: six in c:\other\github\test_easyaug\venv\lib\site-packages (from imgaug->easyaug) (1.16.0)
# Requirement already satisfied: tifffile>=2019.7.26 in c:\other\github\test_easyaug\venv\lib\site-packages (from scikit-image>=0.14.2->imgaug->easyaug) (2022.3.25)
# Requirement already satisfied: PyWavelets>=1.1.1 in c:\other\github\test_easyaug\venv\lib\site-packages (from scikit-image>=0.14.2->imgaug->easyaug) (1.3.0)
# Requirement already satisfied: networkx>=2.2 in c:\other\github\test_easyaug\venv\lib\site-packages (from scikit-image>=0.14.2->imgaug->easyaug) (2.7.1)
# Requirement already satisfied: packaging>=20.0 in c:\other\github\test_easyaug\venv\lib\site-packages (from scikit-image>=0.14.2->imgaug->easyaug) (21.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\other\github\test_easyaug\venv\lib\site-packages (from packaging>=20.0->scikit-image>=0.14.2->imgaug->easyaug) (3.0.7)
# Requirement already satisfied: fonttools>=4.22.0 in c:\other\github\test_easyaug\venv\lib\site-packages (from matplotlib->easyaug) (4.31.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\other\github\test_easyaug\venv\lib\site-packages (from matplotlib->easyaug) (1.4.2)
# Requirement already satisfied: cycler>=0.10 in c:\other\github\test_easyaug\venv\lib\site-packages (from matplotlib->easyaug) (0.11.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\other\github\test_easyaug\venv\lib\site-packages (from matplotlib->easyaug) (2.8.2)
# WARNING: You are using pip version 21.1.2; however, version 22.0.4 is available.
# You should consider upgrading via the 'C:\Other\Github\test_easyaug\venv\Scripts\python.exe -m pip install --upgrade pip' command.

# %%
import os

# Function to show the directory tree.
def tree(path):
    for root, dirs, files in os.walk(path):
        level = root.replace(path, '').count(os.sep)
        indent = ' ' * 4 * (level)
        print('{}{}/'.format(indent, os.path.basename(root)))
        subindent = ' ' * 4 * (level + 1)
        for f in files:
            print('{}{}'.format(subindent, f))

# %%
# Show the directory tree.
tree('data')
# Out:
# data/
#     test/
#         panda/
#             panda_0.jpg
#     train/
#         panda/
#             panda_0.jpg
#             panda_1.jpg
#             panda_2.jpg
#             panda_3.jpg
#             panda_4.jpg

# %% [markdown]
# # Quickview

# %%
# Quickly viewing the images
from easyaug.quickview import Quickviewer

quickviewer = Quickviewer()
quickviewer.read_all_images('data')
quickviewer.view_images()
# Out:
# Read 6 images.
# Visualized 6 images from a total of 6 possible.

# %% [markdown]
# # Preprocess
# The preprocesser is simple so the directories has to be created manually unlike the two other packages.

# %%
# The new directory for preprocessed images.
tree('data_resized')
# Out:
# data_resized/
#     test_resized/
#         panda_resized/
#             panda_0.jpg
#     train_resized/
#         panda_resized/
#             panda_0.jpg
#             panda_1.jpg
#             panda_2.jpg
#             panda_3.jpg
#             panda_4.jpg

# %%
# Resizing the images to 256x256
from easyaug.preprocess import Preprocesser
preprocesser = Preprocesser()
# First for the training folder.
preprocesser.specify_input_and_output_path('data/train/panda', 'data_resized/train_resized/panda_resized')
preprocesser.run_resize((256, 256))
# Then for the test folder.
preprocesser.specify_input_and_output_path('data/test/panda', 'data_resized/test_resized/panda_resized')
preprocesser.run_resize((256, 256))
# Out:
# data_resized/train_resized/panda_resized/panda_0.jpg
# data_resized/train_resized/panda_resized/panda_1.jpg
# data_resized/train_resized/panda_resized/panda_2.jpg
# data_resized/train_resized/panda_resized/panda_3.jpg
# data_resized/train_resized/panda_resized/panda_4.jpg
# data_resized/test_resized/panda_resized/panda_0.jpg

# %%
tree('data_resized')
# Out:
# data_resized/
#     test_resized/
#         panda_resized/
#             panda_0.jpg
#     train_resized/
#         panda_resized/
#             panda_0.jpg
#             panda_1.jpg
#             panda_2.jpg
#             panda_3.jpg
#             panda_4.jpg

# %% [markdown]
# # Augment

# %%
# Testing first
from easyaug.augment import Augmenter
augmenter = Augmenter()
augmenter.specify_input_path('data')
augmenter.do_rotate()
augmenter.run_view()
# Out:
# c:\other\github\test_easyaug\venv\lib\site-packages\easyaug\augment\run_view.py:35: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
# Then augmenting
augmenter.run_augment()
# Out:
# data_augmented/
# Augmenting image: data_augmented/test_augmented/panda_augmented/panda_0.jpg
# Augmenting image: data_augmented/train_augmented/panda_augmented/panda_0.jpg
# Augmenting image: data_augmented/train_augmented/panda_augmented/panda_1.jpg
# Augmenting image: data_augmented/train_augmented/panda_augmented/panda_2.jpg
# Augmenting image: data_augmented/train_augmented/panda_augmented/panda_3.jpg
# Augmenting image: data_augmented/train_augmented/panda_augmented/panda_4.jpg

# %%
tree('data_augmented')
# Out:
# data_augmented/
#     test_augmented/
#         panda_augmented/
#             panda_0.jpg
#             panda_0_Rotate.jpg
#     train_augmented/
#         panda_augmented/
#             panda_0.jpg
#             panda_0_Rotate.jpg
#             panda_1.jpg
#             panda_1_Rotate.jpg
#             panda_2.jpg
#             panda_2_Rotate.jpg
#             panda_3.jpg
#             panda_3_Rotate.jpg
#             panda_4.jpg
#             panda_4_Rotate.jpg
